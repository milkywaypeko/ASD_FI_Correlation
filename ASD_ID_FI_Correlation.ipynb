# %% [markdown]
# # Find Correlation between ASD Registration and Financial Independence

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Import Library

# %%
import numpy as np # For Array, 
import pandas as pd # For Data
import matplotlib.pyplot as plt # For Graph
import seaborn as sns # For Pretty Graph
import statsmodels.api as sm # For LinearRegression
import statsmodels.formula.api as smf # For LinearRegression
from sklearn.preprocessing import PolynomialFeatures # For data power
from sklearn.model_selection import train_test_split # For resampling
from sklearn.linear_model import LinearRegression # For LinearRegression
from sklearn.metrics import mean_squared_error # For MSE
from sklearn.model_selection import LeaveOneOut # For LOOCV
from sklearn.model_selection import cross_val_score # For Cross Test
from sklearn.model_selection import KFold # For K-Fold
from sklearn.utils import resample # For resampling
from sklearn.metrics import mean_squared_error, explained_variance_score, r2_score #MSE, R2, ExVar error

# %% [markdown]
# ## 2. Import Statistics

# %% [markdown]
# ### 1) Define Name List

# %%
regionDic = {'Seoul':'서울특별시', 'Busan' : '부산광역시', 'Daegu' : '대구광역시', 'Incheon' : '인천광역시', 'Gwangju' : '광주광역시',
             'Daejeon' : '대전광역시', 'Ulsan' : '울산광역시', 'Sejong' : '세종특별자치시', 'Gyeonggi-do' : '경기도',
             'Gangwon-do' : '강원도', 'Chungcheongbuk-do' : '충청북도', 'Chungcheongnam-do' : '충청남도',
             'Jeollabuk-do' : '전라북도', 'Jeollanam-do' : '전라남도',
             'Gyeongsangbuk-do' : '경상북도', 'Gyeongsangnam-do' : '경상남도', 'Jeju' : '제주특별자치도'}

# %%
disabilityDic = {'지체' : 'PD', '뇌병변' : 'BL', '시각' : 'VD', '청각' : 'HD', '언어' : 'LD', '지적장애' : 'ID', '자폐성' : 'ASD',
                 '정신장애' : 'MD', '신장장애' : 'KD', '심장장애' : 'CD', '호흡기' : 'RD', '간' : 'HDB', '안면' : 'FD',
                 '장루요루' : 'IUF', '뇌전증' : 'EP', '발달장애' : 'DD'}

# %% [markdown]
# ### 2)Import CSV

# %% [markdown]
# #### (1) Disabled Population

# %%
disabledPopulation = {}
for EnglishName, KoreanName in regionDic.items():
    disabledPopulation[EnglishName] = pd.read_csv('./Statistics/Disabled/Population of the disabled in {name}.csv'.format(name=EnglishName))
    #Label Disabled Population Statistics
    disabledPopulation[EnglishName].insert(0, '광역자치단체', KoreanName)

# %% [markdown]
# #### (2) Population Statistics

# %%
populationDic = {}
for EnglishName, KoreanName in regionDic.items():
    populationDic[EnglishName] = pd.read_csv('./Statistics/Population/Resident population of {name}.csv'.format(name=EnglishName))
    #Label Population Statistics
    populationDic[EnglishName].insert(0, '광역자치단체', KoreanName)

# %% [markdown]
# #### (3) Financial independence Statistics

# %%
financial_Independence = {}
for EnglishName, KoreanName in regionDic.items():
    financial_Independence[EnglishName] = pd.read_csv('./Statistics/Finance/Financial Independence of {name}.csv'.format(name=EnglishName))
    #Label Population Statistics
    financial_Independence[EnglishName].insert(0, '광역자치단체', KoreanName)

# %% [markdown]
# ### 3) Connect And Merge Statistics

# %%
#Connect Disabled Population Statistics
dataD = pd.concat(disabledPopulation, ignore_index=True)

#Make Statistics For Developmental Disability
dataD['발달장애'] = dataD['지적장애'] + dataD['자폐성']

#Connect Population Statistics
dataP = pd.concat(populationDic, ignore_index=True)

#Connect Finance Statistics
dataF = pd.concat(financial_Independence, ignore_index=True)

# %%
#Merge All Statistics
temp = pd.merge(dataD, dataP)
data = pd.merge(temp, dataF)

# %% [markdown]
# ### 4) rearrange data

# %%
#For label in english
data.rename(columns = {'광역자치단체' : 'RLG', '기초자치단체' : 'BLG', '인구' : 'Population',
                       '재정자립도 (%)' : 'Financial_Independence', '재정자주도 (%)' : 'Financial_often'}, inplace = True)
data.rename(columns = disabilityDic, inplace = True)

# %%
#Make Rate of All Disability
for KoreanName, EnglishName in disabilityDic.items():
    data['{name}_rate'.format(name=EnglishName)] = data[EnglishName] / data['Population']

#Make Rate of Developmental Disability
data['DD_rate'] = data['DD'] / data['Population']

#Make Rate of Developmental Disability of Autistic Spectrum Disorder
data['DD_ASD_rate'] = data['ASD'] / data['DD']

#Save Disability_Statistics to CSV
data.to_csv('Statistics/ALL_Disability_Statistics.csv')

#Show Data
data
# Out:
#          RLG      BLG     PD    BL    VD    HD   LD    ID  ASD    MD  ...  \
# 0      서울특별시      종로구   2661   574   717   905   42   396  111   271  ...
# 1      서울특별시       중구   2613   568   735   809   33   304   67   220  ...
# 2      서울특별시      용산구   3518   804   991  1144   66   530  106   298  ...
# 3      서울특별시      성동구   5460  1219  1193  1581  104   710  174   436  ...
# 4      서울특별시      광진구   5800  1252  1337  1656   94   818  167   521  ...
# ..       ...      ...    ...   ...   ...   ...  ...   ...  ...   ...  ...
# 222     경상남도      산청군   1724   292   544    36  329   322   19   146  ...
# 223     경상남도      함양군   1811   335   658    34  290   250   16   253  ...
# 224     경상남도      거창군   2535   431   788    28  419   382   26   207  ...
# 225     경상남도      합천군   2172   409   988    31  400   382   14   239  ...
# 226  제주특별자치도  제주특별자치도  14395  3567  4142  6490  403  3393  617  1295  ...
#
#       MD_rate   KD_rate   CD_rate   RD_rate  HDB_rate   FD_rate  IUF_rate  \
# 0    0.001674  0.001551  0.000068  0.000142  0.000284  0.000037  0.000210
# 1    0.001612  0.001656  0.000095  0.000198  0.000249  0.000037  0.000264
# 2    0.001215  0.001399  0.000090  0.000179  0.000265  0.000024  0.000277
# 3    0.001411  0.001495  0.000120  0.000304  0.000249  0.000049  0.000275
# 4    0.001420  0.001602  0.000101  0.000172  0.000185  0.000022  0.000286
# ..        ...       ...       ...       ...       ...       ...       ...
# 222  0.004121  0.002625  0.000028  0.000423  0.000452  0.000085  0.000536
# 223  0.006404  0.002050  0.000101  0.000253  0.000405  0.000025  0.000557
# 224  0.003338  0.002613  0.000065  0.000306  0.000339  0.000016  0.000387
# 225  0.005361  0.002265  0.000224  0.000381  0.000314  0.000157  0.000673
# 226  0.001856  0.002133  0.000109  0.000357  0.000275  0.000036  0.000287
#
#       EP_rate   DD_rate  DD_ASD_rate
# 0    0.000124  0.003132     0.218935
# 1    0.000161  0.002718     0.180593
# 2    0.000082  0.002594     0.166667
# 3    0.000126  0.002861     0.196833
# 4    0.000134  0.002684     0.169543
# ..        ...       ...          ...
# 222  0.000198  0.009625     0.055718
# 223  0.000101  0.006733     0.060150
# 224  0.000081  0.006580     0.063725
# 225  0.000224  0.008883     0.035354
# 226  0.000176  0.005748     0.153865
#
# [227 rows x 38 columns]

# %% [markdown]
# ## 3. Correlation between ASD and Financial Independence

# %%
#Linear regression (X=Financial_Independence Y=ASD_rate) with statsmodels.formula.api of statsmodels
ASD_rate_ols_smf = smf.ols(formula='ASD_rate ~ Financial_Independence', data=data)

ASD_rate_ols_smf_results = ASD_rate_ols_smf.fit()
ASD_rate_ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     37.09
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           4.83e-09
# Time:                        13:52:34   Log-Likelihood:                 1682.4
# No. Observations:                 227   AIC:                            -3361.
# Df Residuals:                     225   BIC:                            -3354.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0004   1.95e-05     19.406      0.000       0.000       0.000
# Financial_Independence  4.873e-06      8e-07      6.090      0.000     3.3e-06    6.45e-06
# ==============================================================================
# Omnibus:                       10.682   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.519
# Skew:                           0.437   Prob(JB):                      0.00315
# Kurtosis:                       3.673   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Draw a graph (X=Financial_Independence Y=ASD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='ASD_rate', data=data)
plt.show()

# %% [markdown]
# # For Additional Infomation

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Linear regression (X=Financial_Independence Y=ID_rate) with statsmodels.formula.api of statsmodels

# %%
ID_rate_ols_smf = smf.ols(formula='ID_rate ~ Financial_Independence', data=data)

ID_rate_ols_smf_results = ID_rate_ols_smf.fit()
ID_rate_ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                ID_rate   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     133.8
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.35e-24
# Time:                        13:52:34   Log-Likelihood:                 1092.3
# No. Observations:                 227   AIC:                            -2181.
# Df Residuals:                     225   BIC:                            -2174.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0082      0.000     31.273      0.000       0.008       0.009
# Financial_Independence    -0.0001   1.08e-05    -11.569      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                        6.805   Durbin-Watson:                   0.988
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                6.962
# Skew:                           0.406   Prob(JB):                       0.0308
# Kurtosis:                       2.723   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Draw a graph (X=Financial_Independence Y=ID_rate) with seaborn
sns.regplot(x='Financial_Independence', y='ID_rate', data=data)
plt.show()

# %% [markdown]
# ## 2. Linear regression (X=Financial_Independence Y=DD_rate) with statsmodels.formula.api of statsmodels

# %%
DD_rate_ols_smf = smf.ols(formula='DD_rate ~ Financial_Independence', data=data)

DD_rate_ols_smf_results = DD_rate_ols_smf.fit()
DD_rate_ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                DD_rate   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     129.2
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           5.85e-24
# Time:                        13:52:35   Log-Likelihood:                 1097.4
# No. Observations:                 227   AIC:                            -2191.
# Df Residuals:                     225   BIC:                            -2184.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0086      0.000     33.457      0.000       0.008       0.009
# Financial_Independence    -0.0001   1.05e-05    -11.368      0.000      -0.000   -9.89e-05
# ==============================================================================
# Omnibus:                        7.530   Durbin-Watson:                   1.016
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.783
# Skew:                           0.435   Prob(JB):                       0.0204
# Kurtosis:                       2.741   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Draw a graph (X=Financial_Independence Y=DD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='DD_rate', data=data)
plt.show()

# %% [markdown]
# ## 3. Linear regression (X=Financial_Independence Y=DD_ASD_rate) with statsmodels.formula.api of statsmodels

# %%
DD_ASD_rate_ols_smf = smf.ols(formula='DD_ASD_rate ~ Financial_Independence', data=data)

DD_ASD_rate_ols_smf_results = DD_ASD_rate_ols_smf.fit()
DD_ASD_rate_ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            DD_ASD_rate   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     133.6
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.44e-24
# Time:                        13:52:35   Log-Likelihood:                 372.19
# No. Observations:                 227   AIC:                            -740.4
# Df Residuals:                     225   BIC:                            -733.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0358      0.006      5.719      0.000       0.023       0.048
# Financial_Independence     0.0030      0.000     11.560      0.000       0.002       0.003
# ==============================================================================
# Omnibus:                       34.191   Durbin-Watson:                   0.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.355
# Skew:                           0.859   Prob(JB):                     2.59e-12
# Kurtosis:                       4.641   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Draw a graph (X=Financial_Independence Y=DD_ASD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='DD_ASD_rate', data=data)
plt.show()

# %% [markdown]
# ## 4. Linear regression (X=Financial_Independence Y=All Disability VS ASD with statsmodels.formula.api of statsmodels)

# %%
data['All_Disability'] = data.loc[:, 'PD' : 'EP'].sum(axis=1)

data['ASD_All_Disability_rate'] = data['ASD']/data['All_Disability']
    
ASD_VS_Disability_Rate_ols_smf = smf.ols(formula='ASD_All_Disability_rate ~ Financial_Independence'.format(name=EnglishName), data=data)
ASD_VS_Disability_Rate_ols_smf_results = ASD_VS_Disability_Rate_ols_smf.fit()

ASD_VS_Disability_Rate_ols_smf_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     ASD_All_Disability_rate   R-squared:                       0.370
# Model:                                 OLS   Adj. R-squared:                  0.368
# Method:                      Least Squares   F-statistic:                     132.4
# Date:                     Thu, 27 Apr 2023   Prob (F-statistic):           2.12e-24
# Time:                             13:52:35   Log-Likelihood:                 906.49
# No. Observations:                      227   AIC:                            -1809.
# Df Residuals:                          225   BIC:                            -1802.
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0031      0.001      5.222      0.000       0.002       0.004
# Financial_Independence     0.0003   2.44e-05     11.507      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       77.615   Durbin-Watson:                   1.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              273.358
# Skew:                           1.391   Prob(JB):                     4.38e-60
# Kurtosis:                       7.600   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.regplot(x='Financial_Independence', y='ASD_All_Disability_rate', data=data)
plt.show()

# %% [markdown]
# ## 5. Linear regression (X=Financial_Independence Y=All Disability with statsmodels.formula.api of statsmodels)

# %%
for KoreanName, EnglishName in disabilityDic.items():
    print('=================================== Correlation of ', EnglishName, '===================================')
    Disability_Rate_ols_smf = smf.ols(formula='{name}_rate ~ Financial_Independence'.format(name=EnglishName), data=data)
    Disability_Rate_ols_smf_results = Disability_Rate_ols_smf.fit()
    
    print(Disability_Rate_ols_smf_results.summary())
    
    sns.regplot(x='Financial_Independence', y='{name}_rate'.format(name=EnglishName), data=data)
    plt.show()
    print('')
# Out:
# =================================== Correlation of  PD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                PD_rate   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.443
# Method:                 Least Squares   F-statistic:                     180.6
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.28e-30
# Time:                        13:52:36   Log-Likelihood:                 739.33
# No. Observations:                 227   AIC:                            -1475.
# Df Residuals:                     225   BIC:                            -1468.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0456      0.001     36.720      0.000       0.043       0.048
# Financial_Independence    -0.0007    5.1e-05    -13.439      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                        9.706   Durbin-Watson:                   0.869
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                5.667
# Skew:                           0.207   Prob(JB):                       0.0588
# Kurtosis:                       2.346   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  BL ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                BL_rate   R-squared:                       0.448
# Model:                            OLS   Adj. R-squared:                  0.446
# Method:                 Least Squares   F-statistic:                     182.9
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           6.76e-31
# Time:                        13:52:36   Log-Likelihood:                 1202.4
# No. Observations:                 227   AIC:                            -2401.
# Df Residuals:                     225   BIC:                            -2394.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0076      0.000     47.321      0.000       0.007       0.008
# Financial_Independence -8.965e-05   6.63e-06    -13.524      0.000      -0.000   -7.66e-05
# ==============================================================================
# Omnibus:                        8.367   Durbin-Watson:                   1.059
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                8.252
# Skew:                           0.452   Prob(JB):                       0.0161
# Kurtosis:                       3.231   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  VD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                VD_rate   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.331
# Method:                 Least Squares   F-statistic:                     112.9
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.22e-21
# Time:                        13:52:36   Log-Likelihood:                 1059.8
# No. Observations:                 227   AIC:                            -2116.
# Df Residuals:                     225   BIC:                            -2109.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0092      0.000     30.428      0.000       0.009       0.010
# Financial_Independence    -0.0001   1.24e-05    -10.627      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                      147.586   Durbin-Watson:                   1.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1204.335
# Skew:                           2.511   Prob(JB):                    3.03e-262
# Kurtosis:                      13.105   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  HD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                HD_rate   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     47.30
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           5.94e-11
# Time:                        13:52:37   Log-Likelihood:                 861.36
# No. Observations:                 227   AIC:                            -1719.
# Df Residuals:                     225   BIC:                            -1712.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0139      0.001     19.152      0.000       0.012       0.015
# Financial_Independence    -0.0002   2.98e-05     -6.878      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                       45.661   Durbin-Watson:                   0.492
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.495
# Skew:                           0.941   Prob(JB):                     5.54e-23
# Kurtosis:                       5.701   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  LD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                LD_rate   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.043
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           0.000935
# Time:                        13:52:37   Log-Likelihood:                 1139.0
# No. Observations:                 227   AIC:                            -2274.
# Df Residuals:                     225   BIC:                            -2267.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0015      0.000      7.249      0.000       0.001       0.002
# Financial_Independence  -2.94e-05   8.77e-06     -3.354      0.001   -4.67e-05   -1.21e-05
# ==============================================================================
# Omnibus:                      188.195   Durbin-Watson:                   0.303
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1722.468
# Skew:                           3.494   Prob(JB):                         0.00
# Kurtosis:                      14.544   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  ID ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                ID_rate   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     133.8
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.35e-24
# Time:                        13:52:38   Log-Likelihood:                 1092.3
# No. Observations:                 227   AIC:                            -2181.
# Df Residuals:                     225   BIC:                            -2174.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0082      0.000     31.273      0.000       0.008       0.009
# Financial_Independence    -0.0001   1.08e-05    -11.569      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                        6.805   Durbin-Watson:                   0.988
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                6.962
# Skew:                           0.406   Prob(JB):                       0.0308
# Kurtosis:                       2.723   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  ASD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     37.09
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           4.83e-09
# Time:                        13:52:38   Log-Likelihood:                 1682.4
# No. Observations:                 227   AIC:                            -3361.
# Df Residuals:                     225   BIC:                            -3354.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0004   1.95e-05     19.406      0.000       0.000       0.000
# Financial_Independence  4.873e-06      8e-07      6.090      0.000     3.3e-06    6.45e-06
# ==============================================================================
# Omnibus:                       10.682   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.519
# Skew:                           0.437   Prob(JB):                      0.00315
# Kurtosis:                       3.673   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  MD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                MD_rate   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     98.48
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.75e-19
# Time:                        13:52:38   Log-Likelihood:                 1228.6
# No. Observations:                 227   AIC:                            -2453.
# Df Residuals:                     225   BIC:                            -2446.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0038      0.000     26.511      0.000       0.004       0.004
# Financial_Independence -5.862e-05   5.91e-06     -9.924      0.000   -7.03e-05    -4.7e-05
# ==============================================================================
# Omnibus:                       69.969   Durbin-Watson:                   1.622
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.723
# Skew:                           1.391   Prob(JB):                     6.95e-39
# Kurtosis:                       6.292   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  KD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                KD_rate   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     38.55
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           2.55e-09
# Time:                        13:52:39   Log-Likelihood:                 1481.1
# No. Observations:                 227   AIC:                            -2958.
# Df Residuals:                     225   BIC:                            -2951.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0021   4.73e-05     45.080      0.000       0.002       0.002
# Financial_Independence -1.206e-05   1.94e-06     -6.208      0.000   -1.59e-05   -8.23e-06
# ==============================================================================
# Omnibus:                       43.377   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              170.810
# Skew:                           0.687   Prob(JB):                     8.11e-38
# Kurtosis:                       7.021   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  CD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                CD_rate   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     6.625
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):             0.0107
# Time:                        13:52:39   Log-Likelihood:                 1911.2
# No. Observations:                 227   AIC:                            -3818.
# Df Residuals:                     225   BIC:                            -3811.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0001   7.12e-06     16.913      0.000       0.000       0.000
# Financial_Independence -7.517e-07   2.92e-07     -2.574      0.011   -1.33e-06   -1.76e-07
# ==============================================================================
# Omnibus:                       87.979   Durbin-Watson:                   1.700
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              307.352
# Skew:                           1.607   Prob(JB):                     1.82e-67
# Kurtosis:                       7.708   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  RD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                RD_rate   R-squared:                       0.204
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     57.54
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           8.67e-13
# Time:                        13:52:39   Log-Likelihood:                 1738.1
# No. Observations:                 227   AIC:                            -3472.
# Df Residuals:                     225   BIC:                            -3465.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0004   1.53e-05     24.444      0.000       0.000       0.000
# Financial_Independence -4.748e-06   6.26e-07     -7.585      0.000   -5.98e-06   -3.51e-06
# ==============================================================================
# Omnibus:                      158.022   Durbin-Watson:                   1.760
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1982.314
# Skew:                           2.550   Prob(JB):                         0.00
# Kurtosis:                      16.549   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  HDB ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               HDB_rate   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     23.26
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           2.60e-06
# Time:                        13:52:40   Log-Likelihood:                 1777.1
# No. Observations:                 227   AIC:                            -3550.
# Df Residuals:                     225   BIC:                            -3543.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0003   1.28e-05     26.992      0.000       0.000       0.000
# Financial_Independence -2.542e-06   5.27e-07     -4.823      0.000   -3.58e-06    -1.5e-06
# ==============================================================================
# Omnibus:                       65.422   Durbin-Watson:                   1.362
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.154
# Skew:                           1.314   Prob(JB):                     4.54e-35
# Kurtosis:                       6.133   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  FD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                FD_rate   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     18.12
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           3.05e-05
# Time:                        13:52:40   Log-Likelihood:                 2021.0
# No. Observations:                 227   AIC:                            -4038.
# Df Residuals:                     225   BIC:                            -4031.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept               7.659e-05   4.39e-06     17.465      0.000    6.79e-05    8.52e-05
# Financial_Independence -7.662e-07    1.8e-07     -4.257      0.000   -1.12e-06   -4.12e-07
# ==============================================================================
# Omnibus:                       62.003   Durbin-Watson:                   1.491
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              149.677
# Skew:                           1.243   Prob(JB):                     3.15e-33
# Kurtosis:                       6.106   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  IUF ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               IUF_rate   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     103.7
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           2.85e-20
# Time:                        13:52:41   Log-Likelihood:                 1723.5
# No. Observations:                 227   AIC:                            -3443.
# Df Residuals:                     225   BIC:                            -3436.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0005   1.63e-05     31.667      0.000       0.000       0.001
# Financial_Independence -6.797e-06   6.68e-07    -10.183      0.000   -8.11e-06   -5.48e-06
# ==============================================================================
# Omnibus:                       31.378   Durbin-Watson:                   1.343
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.663
# Skew:                           0.798   Prob(JB):                     2.71e-11
# Kurtosis:                       4.613   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  EP ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                EP_rate   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     68.64
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.06e-14
# Time:                        13:52:41   Log-Likelihood:                 1834.9
# No. Observations:                 227   AIC:                            -3666.
# Df Residuals:                     225   BIC:                            -3659.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0002   9.96e-06     23.706      0.000       0.000       0.000
# Financial_Independence -3.385e-06   4.09e-07     -8.285      0.000   -4.19e-06   -2.58e-06
# ==============================================================================
# Omnibus:                       58.428   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              138.994
# Skew:                           1.176   Prob(JB):                     6.57e-31
# Kurtosis:                       6.027   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# =================================== Correlation of  DD ===================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                DD_rate   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.362
# Method:                 Least Squares   F-statistic:                     129.2
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           5.85e-24
# Time:                        13:52:41   Log-Likelihood:                 1097.4
# No. Observations:                 227   AIC:                            -2191.
# Df Residuals:                     225   BIC:                            -2184.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.0086      0.000     33.457      0.000       0.008       0.009
# Financial_Independence    -0.0001   1.05e-05    -11.368      0.000      -0.000   -9.89e-05
# ==============================================================================
# Omnibus:                        7.530   Durbin-Watson:                   1.016
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.783
# Skew:                           0.435   Prob(JB):                       0.0204
# Kurtosis:                       2.741   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # For Additional data analysis (For Computer Science)

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Linear regression with sklearn

# %% [markdown]
# ### 1) Linear regression (X=Financial_Independence Y=ASD_rate) with sklearn

# %%
ols_ASD_rate_skl = LinearRegression(fit_intercept=True)

ASD_rate_skl_X_train = data['Financial_Independence'].values.reshape(-1, 1)
ASD_rate_skl_y_true = data['ASD_rate']

ols_ASD_rate_skl.fit(ASD_rate_skl_X_train, ASD_rate_skl_y_true)
print('Intercept : ', ols_ASD_rate_skl.intercept_, 'Coef : ', ols_ASD_rate_skl.coef_)
ols_ASD_rate_skl_pre = ols_ASD_rate_skl.predict(data['Financial_Independence'].values.reshape(-1, 1))

ols_ASD_rate_skl_summary = { 'R2' : r2_score(ASD_rate_skl_y_true, ols_ASD_rate_skl_pre),
                  'Ex. Var' : explained_variance_score(ASD_rate_skl_y_true, ols_ASD_rate_skl_pre),
                  'MSE' : mean_squared_error(ASD_rate_skl_y_true, ols_ASD_rate_skl_pre)}

for k, v in ols_ASD_rate_skl_summary.items():
    print(k,':', v)
# Out:
# Intercept :  0.0003783280285715549 Coef :  [4.87333138e-06]
# R2 : 0.1415222123800275
# Ex. Var : 0.1415222123800275
# MSE : 2.1384062195390713e-08

# %% [markdown]
# ### 2) Draw a graph (X=Financial_Independence Y=ASD_rate) with matplotlib

# %%
ols_ASD_rate_skl_x = np.arange(0, 70, 0.1)
ols_ASD_rate_skl_y = [ols_ASD_rate_skl.coef_*x + ols_ASD_rate_skl.intercept_ for x in ols_ASD_rate_skl_x]
plt.scatter(data['Financial_Independence'], data['ASD_rate'])
plt.plot(ols_ASD_rate_skl_x, ols_ASD_rate_skl_y)
plt.xlabel('Financial_Independence')
plt.ylabel('ASD_rate')
plt.show()

# %% [markdown]
# ## 2. Linear regression with statsmodels

# %% [markdown]
# ### 1) Linear regression (X=Financial_Independence Y=ASD_rate) with statsmodels..api of statsmodels

# %%
ASD_rate_sm_X_train = data['Financial_Independence']
ASD_rate_sm_y_true = data['ASD_rate']

ASD_rate_ols_sm = sm.OLS(ASD_rate_sm_y_true, sm.add_constant(ASD_rate_sm_X_train))

ASD_rate_ols_sm_results = ASD_rate_ols_sm.fit()
ASD_rate_ols_sm_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     37.09
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           4.83e-09
# Time:                        13:52:42   Log-Likelihood:                 1682.4
# No. Observations:                 227   AIC:                            -3361.
# Df Residuals:                     225   BIC:                            -3354.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0004   1.95e-05     19.406      0.000       0.000       0.000
# Financial_Independence  4.873e-06      8e-07      6.090      0.000     3.3e-06    6.45e-06
# ==============================================================================
# Omnibus:                       10.682   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.519
# Skew:                           0.437   Prob(JB):                      0.00315
# Kurtosis:                       3.673   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### 2)Draw a graph (X=Financial_Independence Y=ASD_rate) with matplotlib

# %%
FI_OLS_x = np.arange(0, 70, 0.1)
FI_OLS_y = [ASD_rate_ols_sm_results.predict([1, x]) for x in FI_OLS_x]
plt.scatter(data['Financial_Independence'], data['ASD_rate'])
plt.plot(FI_OLS_x, FI_OLS_y)
plt.xlabel('Financial_Independence')
plt.ylabel('ASD_rate')
plt.show()

# %% [markdown]
# ## 3. MSE resampling test

# %%
# Make Polynomial Maximum 20
Financial_Independence_pol = PolynomialFeatures(degree=30, interaction_only=False, include_bias=False) 

# polf[0] power 1, polf[1] power 2, polf[2] power 3, polf[3] power 4, polf[4] power 5...
Financial_Independence_polf = Financial_Independence_pol.fit_transform(data.loc[:, 'Financial_Independence'].values.reshape(-1, 1))

# %% [markdown]
# ### 1) Resampling 50% degree 1 to 20

# %%
#For Resampling
X, y = Financial_Independence_polf, data.ASD_rate 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=10)

# ols model with intercept and Power
lm = [LinearRegression()]*20
for i in range(0, 20):
    lm[i] = LinearRegression(fit_intercept=True)

# Fitting
lm_fit = [LinearRegression()]*20
lm_fit[0] = lm[0].fit(X_train[ : ,0].reshape(-1, 1), y_train)
for i in range(1, 20):
    lm_fit[i] = lm[i].fit(X_train[ : ,0 : i+1], y_train)

# Predict
lm_predict = [np.ndarray(len(y_test))]*20
lm_predict[0] = lm_fit[0].predict(X_test[ : ,0].reshape(-1, 1))
for i in range(1, 20):
    lm_predict[i] = lm_fit[i].predict(X_test[ : , 0 : i + 1])
    
# Make MSE
lm_MSE = np.ndarray(20)
for i in range(0, 20):
    lm_MSE[i] = mean_squared_error(y_test, lm_predict[i])
    print('lm_MSE[{num}] : '.format(num=i), lm_MSE[i])
# Out:
# lm_MSE[0] :  2.472140177156666e-08
# lm_MSE[1] :  2.4038202304554926e-08
# lm_MSE[2] :  2.366559650519523e-08
# lm_MSE[3] :  2.3074159590908934e-08
# lm_MSE[4] :  2.326225443249408e-08
# lm_MSE[5] :  2.3415079832653094e-08
# lm_MSE[6] :  3.2303598071340635e-08
# lm_MSE[7] :  1.2934433667051017e-07
# lm_MSE[8] :  1.3670746495383123e-07
# lm_MSE[9] :  5.8942368791152706e-08
# lm_MSE[10] :  2.2709806265425524e-07
# lm_MSE[11] :  3.586519908523862e-06
# lm_MSE[12] :  2.061082987249113e-05
# lm_MSE[13] :  1.089715623106417e-06
# lm_MSE[14] :  8.279002589123958e-08
# lm_MSE[15] :  8.682173906292938e-07
# lm_MSE[16] :  3.499152513902354e-06
# lm_MSE[17] :  2.230690274879541e-06
# lm_MSE[18] :  9.810521363260602e-06
# lm_MSE[19] :  0.0002445267939730473

# %% [markdown]
# #### (1) Draw a graph (X=Power Y=MSE) with seaborn

# %%
MSE_X = np.arange(1, 21)
MSE_y = lm_MSE
sns.lineplot(x = MSE_X, y = MSE_y) 
plt.xlabel('Power')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ### 2) For LOOCV splits data

# %%
X, y = Financial_Independence_polf, data.ASD_rate 

loocv = LeaveOneOut()
loocv.get_n_splits(X)
# Out:
# 227

# %%
#For LOOCV Make MSE
lm = [LinearRegression(fit_intercept=True)] * 20
lm_fit = [LinearRegression(fit_intercept=True)] * 20
lm_predict = [np.ndarray] * 20
loocvMSE = []
for i in np.arange(0, 20):
    loocv_mse = []
    for train_index, test_index in loocv.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        if(i==0):
            lm_fit[0] = lm[0].fit(X_train[ : ,0].reshape(-1, 1), y_train)
            lm_predict[0] = lm_fit[0].predict(X_test[ : ,0].reshape(-1, 1))
        else:
            lm_fit[i] = lm[i].fit(X_train[ : ,0 : i+1], y_train)
            lm_predict[i] = lm_fit[i].predict(X_test[ : ,0 : i+1])
        
        loocv_mse.append(mean_squared_error(y_test, lm_predict[i]))
    loocvMSE.append(np.array(loocv_mse).mean())
    print('lm[', str(i), '] MSE : ', loocvMSE[i])
# Out:
# lm[ 0 ] MSE :  2.1827010580636265e-08
# lm[ 1 ] MSE :  2.1184676851991948e-08
# lm[ 2 ] MSE :  2.1266190246591373e-08
# lm[ 3 ] MSE :  2.058752233315883e-08
# lm[ 4 ] MSE :  2.0810022376377935e-08
# lm[ 5 ] MSE :  2.1481451301680224e-08
# lm[ 6 ] MSE :  2.270031959737948e-08
# lm[ 7 ] MSE :  2.119517231231023e-08
# lm[ 8 ] MSE :  2.7148930299039243e-08
# lm[ 9 ] MSE :  7.763212021675012e-08
# lm[ 10 ] MSE :  2.341293806365176e-07
# lm[ 11 ] MSE :  6.188648873484746e-07
# lm[ 12 ] MSE :  1.3612958637576527e-06
# lm[ 13 ] MSE :  2.1222751609326556e-07
# lm[ 14 ] MSE :  8.985830492801572e-07
# lm[ 15 ] MSE :  3.3660953529922977e-06
# lm[ 16 ] MSE :  1.0489181223991245e-05
# lm[ 17 ] MSE :  2.779634468122506e-05
# lm[ 18 ] MSE :  6.528143069781475e-05
# lm[ 19 ] MSE :  0.0001398417304828336

# %% [markdown]
# #### (1) Draw a graph (X=Power Y=MSE) with seaborn

# %%
MSE_LOOCV_X = np.arange(1, 21)
MSE_LOOCV_y = np.array(loocvMSE)
sns.lineplot(x = MSE_LOOCV_X, y = MSE_LOOCV_y) 
plt.xlabel('Power')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ### 3) For Cross Test LOOCV splits data

# %%
# For Cross Test LOOCV
lm = [LinearRegression(fit_intercept=True)]*20
scoreMSE = []

for i in np.arange(0, 20):
    if(i==0):
        cval = cross_val_score(lm[i],
                                    Financial_Independence_polf[:, 0].reshape(-1, 1),
                                    data.ASD_rate ,
                                    cv=len(data), # k=n k-Fold -> LOOCV
                                    n_jobs=-1,
                                    scoring='neg_mean_squared_error')
        scoreMSE.append(-cval.mean())
        
    else:
        cval = cross_val_score(lm[i],
                                    Financial_Independence_polf[:, 0 : i+1],
                                    data.ASD_rate ,
                                    cv=len(data), # k=n k-Fold -> LOOCV
                                    n_jobs=-1,
                                    scoring='neg_mean_squared_error')
        scoreMSE.append(-cval.mean())
    print('lm[', str(i), '] MSE : ', scoreMSE[i])
# Out:
# lm[ 0 ] MSE :  2.1827010580636265e-08
# lm[ 1 ] MSE :  2.1184676851991948e-08
# lm[ 2 ] MSE :  2.1266190246591373e-08
# lm[ 3 ] MSE :  2.058752233315883e-08
# lm[ 4 ] MSE :  2.0810022376377935e-08
# lm[ 5 ] MSE :  2.1481451301680224e-08
# lm[ 6 ] MSE :  2.270031959737948e-08
# lm[ 7 ] MSE :  2.119517231231023e-08
# lm[ 8 ] MSE :  2.7148930299039243e-08
# lm[ 9 ] MSE :  7.763212021675012e-08
# lm[ 10 ] MSE :  2.341293806365176e-07
# lm[ 11 ] MSE :  6.188648873484746e-07
# lm[ 12 ] MSE :  1.3612958637576527e-06
# lm[ 13 ] MSE :  2.1222751609326556e-07
# lm[ 14 ] MSE :  8.985830492801572e-07
# lm[ 15 ] MSE :  3.3660953529922977e-06
# lm[ 16 ] MSE :  1.0489181223991245e-05
# lm[ 17 ] MSE :  2.779634468122506e-05
# lm[ 18 ] MSE :  6.528143069781475e-05
# lm[ 19 ] MSE :  0.0001398417304828336

# %% [markdown]
# #### (1) Draw a graph (X=Power Y=MSE) with seaborn

# %%
MSE_score_X = np.arange(1, 21)
MSE_score_y = np.array(scoreMSE)
sns.lineplot(x = MSE_score_X, y = MSE_score_y) 
plt.xlabel('Power')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# ### 4)For K-Fold Make MSE

# %%
#Load K-Fold Model
X, y = Financial_Independence_polf, data.ASD_rate 
kf = KFold(n_splits=10, shuffle=True, random_state=10)

# %%
#For K-Fold Make MSE
kf_poly = []

for i in range(0, 20):
    kf_mse = []
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        if i == 0:
            X_TRAIN = X_train[:, 0:1]
            X_TEST = X_test[:,0:1]
            
        else:
            X_TRAIN = X_train[:, 0:i+1]
            X_TEST = X_test[:,0:i+1]
        kf_mse.append(
            mean_squared_error(
                y_test,
                LinearRegression(fit_intercept=True)
                                 .fit(
                                     X_TRAIN,
                                     y_train
                                 )
                                 .predict(
                                     X_TEST
                                 )
                            )
                        )
    kf_poly.append(np.array(kf_mse).mean())
    print('lm' + str(i + 1) + '_MSE : ', kf_poly[i])

MSE_KFold_X = np.arange(1, 21)
MSE_KFold_y = np.array(kf_poly)
MSE_KFold_y
sns.lineplot(x = MSE_KFold_X, y = MSE_KFold_y) 
plt.xlabel('Power')
plt.ylabel('MSE')
plt.show()
# Out:
# lm1_MSE :  2.2004386628875767e-08
# lm2_MSE :  2.1249992113287843e-08
# lm3_MSE :  2.1283436722240946e-08
# lm4_MSE :  2.0755558603118407e-08
# lm5_MSE :  2.09284347616665e-08
# lm6_MSE :  2.131062390310669e-08
# lm7_MSE :  2.3308727479860436e-08
# lm8_MSE :  2.152070111438327e-08
# lm9_MSE :  2.8236169509063545e-08
# lm10_MSE :  6.748816451152616e-08
# lm11_MSE :  2.184847067841498e-07
# lm12_MSE :  6.486218384267818e-07
# lm13_MSE :  1.6328866153841268e-06
# lm14_MSE :  2.784863322149363e-07
# lm15_MSE :  9.265170108516126e-07
# lm16_MSE :  2.830619338620158e-06
# lm17_MSE :  7.588893987324942e-06
# lm18_MSE :  1.8386054268324413e-05
# lm19_MSE :  4.164608630786739e-05
# lm20_MSE :  9.411350959605876e-05

# %% [markdown]
# ### 5)Linear regression (X=Financial_Independence^4 Y=ASD_rate) with statsmodels..api of statsmodels

# %%
ASD_rate_4_X_train = Financial_Independence_polf[ : ,0 : 4]
ASD_rate_4_y_true = data['ASD_rate']

ASD_rate_4_ols_sm = sm.OLS(ASD_rate_4_y_true, sm.add_constant(ASD_rate_4_X_train))

ASD_rate_4_ols_sm_results = ASD_rate_4_ols_sm.fit()
ASD_rate_4_ols_sm_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     14.67
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.20e-10
# Time:                        13:53:04   Log-Likelihood:                 1691.7
# No. Observations:                 227   AIC:                            -3373.
# Df Residuals:                     222   BIC:                            -3356.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -1.8e-05      0.000     -0.175      0.861      -0.000       0.000
# x1          6.886e-05   1.78e-05      3.858      0.000    3.37e-05       0.000
# x2          -3.21e-06   9.98e-07     -3.217      0.001   -5.18e-06   -1.24e-06
# x3          6.328e-08   2.17e-08      2.922      0.004    2.06e-08    1.06e-07
# x4         -4.297e-10   1.57e-10     -2.731      0.007    -7.4e-10    -1.2e-10
# ==============================================================================
# Omnibus:                       13.284   Durbin-Watson:                   1.392
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.531
# Skew:                           0.423   Prob(JB):                     0.000156
# Kurtosis:                       4.067   Cond. No.                     2.97e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### (1) Draw a graph (X=Financial_Independence^4 Y=ASD_rate) with matplotlib

# %%
FI_OLS_4_x = np.arange(0, 70, 0.1)

FI_OLS_4_y = [ASD_rate_4_ols_sm_results.predict([np.power(x, i) for i in range(0, 5)]) for x in FI_OLS_4_x]
plt.scatter(data['Financial_Independence'], data['ASD_rate'])
plt.plot(FI_OLS_4_x, FI_OLS_4_y)
plt.xlabel('Financial_Independence')
plt.ylabel('ASD_rate')
plt.show()

# %% [markdown]
# ### (2) Draw a graph (X=Financial_Independence^4 Y=ASD_rate) with seaborn

# %%
sns.regplot(x='Financial_Independence', y='ASD_rate', data=data, order = 4)
plt.show()

# %% [markdown]
# ##### This model Lower MSE but hard to interprint

# %% [markdown]
# ### 6)Linear regression (X=Financial_Independence Y=ASD_rate) power with statsmodels..api of statsmodels

# %%
for i in range(0, 15):
    ASD_rate_for_X_train = Financial_Independence_polf[ : , 0: i + 1]
    ASD_rate_for_y_true = data['ASD_rate']

    ASD_rate_for_ols_sm = sm.OLS(ASD_rate_for_y_true, sm.add_constant(ASD_rate_for_X_train))

    ASD_rate_for_ols_sm_results = ASD_rate_for_ols_sm.fit()
    print(ASD_rate_for_ols_sm_results.summary())
    plt.ylim([0, 0.0011]) 
    sns.regplot(x='Financial_Independence', y='ASD_rate', data=data, order = i + 1)
    plt.show()

#seaborn overfitting error from 16
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.138
# Method:                 Least Squares   F-statistic:                     37.09
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           4.83e-09
# Time:                        13:53:05   Log-Likelihood:                 1682.4
# No. Observations:                 227   AIC:                            -3361.
# Df Residuals:                     225   BIC:                            -3354.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004   1.95e-05     19.406      0.000       0.000       0.000
# x1          4.873e-06      8e-07      6.090      0.000     3.3e-06    6.45e-06
# ==============================================================================
# Omnibus:                       10.682   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               11.519
# Skew:                           0.437   Prob(JB):                      0.00315
# Kurtosis:                       3.673   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.164
# Method:                 Least Squares   F-statistic:                     23.12
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           7.44e-10
# Time:                        13:53:05   Log-Likelihood:                 1686.4
# No. Observations:                 227   AIC:                            -3367.
# Df Residuals:                     224   BIC:                            -3356.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003   3.43e-05      8.684      0.000       0.000       0.000
# x1          1.231e-05   2.74e-06      4.484      0.000     6.9e-06    1.77e-05
# x2         -1.288e-07   4.56e-08     -2.828      0.005   -2.19e-07   -3.91e-08
# ==============================================================================
# Omnibus:                       13.419   Durbin-Watson:                   1.363
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.026
# Skew:                           0.470   Prob(JB):                     0.000331
# Kurtosis:                       3.900   Cond. No.                     3.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.182
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     16.59
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           9.16e-10
# Time:                        13:53:06   Log-Likelihood:                 1687.9
# No. Observations:                 227   AIC:                            -3368.
# Df Residuals:                     223   BIC:                            -3354.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002   5.94e-05      3.578      0.000    9.54e-05       0.000
# x1          2.434e-05   7.37e-06      3.303      0.001    9.82e-06    3.89e-05
# x2          -5.74e-07   2.57e-07     -2.231      0.027   -1.08e-06   -6.71e-08
# x3          4.546e-09   2.59e-09      1.758      0.080    -5.5e-10    9.64e-09
# ==============================================================================
# Omnibus:                       15.510   Durbin-Watson:                   1.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.270
# Skew:                           0.511   Prob(JB):                     6.54e-05
# Kurtosis:                       3.996   Cond. No.                     2.95e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     14.67
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.20e-10
# Time:                        13:53:06   Log-Likelihood:                 1691.7
# No. Observations:                 227   AIC:                            -3373.
# Df Residuals:                     222   BIC:                            -3356.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -1.8e-05      0.000     -0.175      0.861      -0.000       0.000
# x1          6.886e-05   1.78e-05      3.858      0.000    3.37e-05       0.000
# x2          -3.21e-06   9.98e-07     -3.217      0.001   -5.18e-06   -1.24e-06
# x3          6.328e-08   2.17e-08      2.922      0.004    2.06e-08    1.06e-07
# x4         -4.297e-10   1.57e-10     -2.731      0.007    -7.4e-10    -1.2e-10
# ==============================================================================
# Omnibus:                       13.284   Durbin-Watson:                   1.392
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.531
# Skew:                           0.423   Prob(JB):                     0.000156
# Kurtosis:                       4.067   Cond. No.                     2.97e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.97e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     11.68
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           4.96e-10
# Time:                        13:53:07   Log-Likelihood:                 1691.7
# No. Observations:                 227   AIC:                            -3371.
# Df Residuals:                     221   BIC:                            -3351.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.602e-05      0.000     -0.184      0.854      -0.000       0.000
# x1          7.325e-05   4.44e-05      1.650      0.100   -1.43e-05       0.000
# x2          -3.57e-06   3.48e-06     -1.026      0.306   -1.04e-05    3.29e-06
# x3          7.605e-08    1.2e-07      0.633      0.527   -1.61e-07    3.13e-07
# x4         -6.305e-10   1.86e-09     -0.338      0.736   -4.31e-09    3.04e-09
# x5          1.146e-12   1.06e-11      0.108      0.914   -1.98e-11     2.2e-11
# ==============================================================================
# Omnibus:                       13.200   Durbin-Watson:                   1.393
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.473
# Skew:                           0.419   Prob(JB):                     0.000161
# Kurtosis:                       4.070   Cond. No.                     3.49e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.49e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.212
# Model:                            OLS   Adj. R-squared:                  0.191
# Method:                 Least Squares   F-statistic:                     9.875
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.21e-09
# Time:                        13:53:07   Log-Likelihood:                 1692.1
# No. Observations:                 227   AIC:                            -3370.
# Df Residuals:                     220   BIC:                            -3346.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -0.874      0.383      -0.001       0.000
# x1             0.0002   9.69e-05      1.584      0.115   -3.74e-05       0.000
# x2         -1.222e-05   9.91e-06     -1.233      0.219   -3.18e-05    7.32e-06
# x3          5.154e-07   4.86e-07      1.059      0.291   -4.43e-07    1.47e-06
# x4          -1.19e-08   1.22e-08     -0.973      0.332    -3.6e-08    1.22e-08
# x5          1.418e-10   1.51e-10      0.937      0.350   -1.56e-10     4.4e-10
# x6         -6.762e-13   7.26e-13     -0.932      0.352   -2.11e-12    7.54e-13
# ==============================================================================
# Omnibus:                       12.377   Durbin-Watson:                   1.399
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.374
# Skew:                           0.422   Prob(JB):                     0.000459
# Kurtosis:                       3.956   Cond. No.                     3.99e+11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.99e+11. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     8.473
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           3.59e-09
# Time:                        13:53:07   Log-Likelihood:                 1692.3
# No. Observations:                 227   AIC:                            -3369.
# Df Residuals:                     219   BIC:                            -3341.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.001     -0.929      0.354      -0.002       0.001
# x1             0.0002      0.000      1.239      0.217      -0.000       0.001
# x2         -2.342e-05   2.42e-05     -0.970      0.333    -7.1e-05    2.42e-05
# x3          1.256e-06   1.53e-06      0.818      0.414   -1.77e-06    4.28e-06
# x4         -3.848e-08   5.37e-08     -0.717      0.474   -1.44e-07    6.73e-08
# x5          6.674e-10   1.04e-09      0.639      0.523   -1.39e-09    2.72e-09
# x6         -6.037e-12   1.06e-11     -0.572      0.568   -2.68e-11    1.48e-11
# x7          2.198e-14   4.32e-14      0.509      0.611   -6.32e-14    1.07e-13
# ==============================================================================
# Omnibus:                       12.325   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.088
# Skew:                           0.426   Prob(JB):                     0.000529
# Kurtosis:                       3.932   Cond. No.                     4.42e+13
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+13. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.195
# Method:                 Least Squares   F-statistic:                     8.820
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           1.49e-09
# Time:                        13:53:08   Log-Likelihood:                 1693.3
# No. Observations:                 227   AIC:                            -3371.
# Df Residuals:                     219   BIC:                            -3343.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.277e-07   1.54e-05     -0.047      0.962    -3.1e-05    2.96e-05
# x1          5.132e-07   3.92e-05      0.013      0.990   -7.67e-05    7.77e-05
# x2          1.645e-05   1.17e-05      1.407      0.161   -6.59e-06    3.95e-05
# x3          -2.15e-06    1.3e-06     -1.659      0.099    -4.7e-06    4.04e-07
# x4          1.252e-07   7.26e-08      1.726      0.086   -1.78e-08    2.68e-07
# x5         -3.934e-09   2.26e-09     -1.742      0.083   -8.39e-09    5.18e-10
# x6          6.872e-11   3.96e-11      1.736      0.084    -9.3e-12    1.47e-10
# x7         -6.269e-13   3.65e-13     -1.718      0.087   -1.35e-12    9.25e-14
# x8          2.325e-15   1.38e-15      1.689      0.093   -3.87e-16    5.04e-15
# ==============================================================================
# Omnibus:                       11.435   Durbin-Watson:                   1.413
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.577
# Skew:                           0.413   Prob(JB):                      0.00113
# Kurtosis:                       3.868   Cond. No.                     5.20e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.2e+15. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                       0.148
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     6.368
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):           3.38e-06
# Time:                        13:53:08   Log-Likelihood:                 1683.2
# No. Observations:                 227   AIC:                            -3352.
# Df Residuals:                     220   BIC:                            -3328.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        7.69e-09   5.01e-10     15.343      0.000     6.7e-09    8.68e-09
# x1           6.07e-08   3.95e-09     15.350      0.000    5.29e-08    6.85e-08
# x2          4.117e-07   2.68e-08     15.363      0.000    3.59e-07    4.64e-07
# x3          1.705e-06   1.11e-07     15.405      0.000    1.49e-06    1.92e-06
# x4         -2.382e-07   1.88e-08    -12.636      0.000   -2.75e-07   -2.01e-07
# x5          1.376e-08   1.25e-09     10.975      0.000    1.13e-08    1.62e-08
# x6         -4.171e-10   4.24e-11     -9.847      0.000   -5.01e-10   -3.34e-10
# x7          6.966e-12   7.72e-13      9.019      0.000    5.44e-12    8.49e-12
# x8         -6.066e-14   7.24e-15     -8.376      0.000   -7.49e-14   -4.64e-14
# x9          2.152e-16   2.74e-17      7.852      0.000    1.61e-16    2.69e-16
# ==============================================================================
# Omnibus:                        4.852   Durbin-Watson:                   1.464
# Prob(Omnibus):                  0.088   Jarque-Bera (JB):                5.149
# Skew:                           0.212   Prob(JB):                       0.0762
# Kurtosis:                       3.604   Cond. No.                     1.20e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.2e+18. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -0.248
# Model:                            OLS   Adj. R-squared:                 -0.282
# Method:                 Least Squares   F-statistic:                    -7.282
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:09   Log-Likelihood:                 1639.9
# No. Observations:                 227   AIC:                            -3266.
# Df Residuals:                     220   BIC:                            -3242.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.991e-11   1.95e-12     15.313      0.000    2.61e-11    3.38e-11
# x1          1.212e-10   7.91e-12     15.320      0.000    1.06e-10    1.37e-10
# x2          3.014e-09   1.97e-10     15.319      0.000    2.63e-09     3.4e-09
# x3          2.356e-08   1.54e-09     15.327      0.000    2.05e-08    2.66e-08
# x4           1.12e-07    7.3e-09     15.351      0.000    9.77e-08    1.26e-07
# x5         -1.518e-08   1.13e-09    -13.417      0.000   -1.74e-08   -1.29e-08
# x6          8.405e-10   6.93e-11     12.132      0.000    7.04e-10    9.77e-10
# x7         -2.437e-11   2.17e-12    -11.207      0.000   -2.87e-11   -2.01e-11
# x8          3.897e-13   3.71e-14     10.507      0.000    3.17e-13    4.63e-13
# x9         -3.259e-15   3.27e-16     -9.955      0.000    -3.9e-15   -2.61e-15
# x10         1.114e-17   1.17e-18      9.505      0.000    8.83e-18    1.34e-17
# ==============================================================================
# Omnibus:                        1.030   Durbin-Watson:                   1.306
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.726
# Skew:                           0.097   Prob(JB):                        0.696
# Kurtosis:                       3.197   Cond. No.                     5.73e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.73e+19. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -0.937
# Model:                            OLS   Adj. R-squared:                 -0.990
# Method:                 Least Squares   F-statistic:                    -17.74
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:09   Log-Likelihood:                 1590.0
# No. Observations:                 227   AIC:                            -3166.
# Df Residuals:                     220   BIC:                            -3142.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.157e-14    4.7e-15     13.112      0.000    5.23e-14    7.08e-14
# x1          3.852e-11   2.94e-12     13.112      0.000    3.27e-11    4.43e-11
# x2          1.008e-11   7.69e-13     13.115      0.000    8.57e-12    1.16e-11
# x3          1.118e-10   8.52e-12     13.117      0.000     9.5e-11    1.29e-10
# x4           9.88e-10   7.53e-11     13.122      0.000     8.4e-10    1.14e-09
# x5          5.211e-09   3.97e-10     13.137      0.000    4.43e-09    5.99e-09
# x6         -6.738e-10   5.75e-11    -11.726      0.000   -7.87e-10   -5.61e-10
# x7          3.562e-11   3.32e-12     10.715      0.000    2.91e-11    4.22e-11
# x8         -9.887e-13   9.93e-14     -9.955      0.000   -1.18e-12   -7.93e-13
# x9           1.52e-14   1.62e-15      9.364      0.000     1.2e-14    1.84e-14
# x10        -1.226e-16   1.38e-17     -8.894      0.000    -1.5e-16   -9.54e-17
# x11         4.059e-19   4.77e-20      8.511      0.000    3.12e-19       5e-19
# ==============================================================================
# Omnibus:                        0.306   Durbin-Watson:                   1.101
# Prob(Omnibus):                  0.858   Jarque-Bera (JB):                0.413
# Skew:                           0.078   Prob(JB):                        0.813
# Kurtosis:                       2.861   Cond. No.                     1.44e+22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.44e+22. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -1.723
# Model:                            OLS   Adj. R-squared:                 -1.785
# Method:                 Least Squares   F-statistic:                    -27.97
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:10   Log-Likelihood:                 1551.4
# No. Observations:                 227   AIC:                            -3091.
# Df Residuals:                     221   BIC:                            -3070.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.337e-17    8.1e-18     11.528      0.000    7.74e-17    1.09e-16
# x1           2.31e-12      2e-13     11.527      0.000    1.92e-12    2.71e-12
# x2          2.408e-14   2.09e-15     11.528      0.000       2e-14    2.82e-14
# x3          3.057e-13   2.65e-14     11.530      0.000    2.53e-13    3.58e-13
# x4          3.756e-12   3.26e-13     11.531      0.000    3.11e-12     4.4e-12
# x5           3.61e-11   3.13e-12     11.535      0.000    2.99e-11    4.23e-11
# x6          2.048e-10   1.77e-11     11.545      0.000     1.7e-10     2.4e-10
# x7         -2.538e-11   2.42e-12    -10.474      0.000   -3.02e-11   -2.06e-11
# x8          1.288e-12   1.33e-13      9.652      0.000    1.02e-12    1.55e-12
# x9          -3.44e-14   3.82e-15     -9.000      0.000   -4.19e-14   -2.69e-14
# x10         5.104e-16   6.02e-17      8.474      0.000    3.92e-16    6.29e-16
# x11        -3.988e-18   4.96e-19     -8.042      0.000   -4.97e-18   -3.01e-18
# x12         1.282e-20   1.67e-21      7.684      0.000    9.54e-21    1.61e-20
# ==============================================================================
# Omnibus:                        0.927   Durbin-Watson:                   1.015
# Prob(Omnibus):                  0.629   Jarque-Bera (JB):                0.961
# Skew:                          -0.033   Prob(JB):                        0.618
# Kurtosis:                       2.688   Cond. No.                     6.44e+24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.44e+24. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -4.213
# Model:                            OLS   Adj. R-squared:                 -4.331
# Method:                 Least Squares   F-statistic:                    -35.72
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:10   Log-Likelihood:                 1477.6
# No. Observations:                 227   AIC:                            -2943.
# Df Residuals:                     221   BIC:                            -2923.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.147e-24    1.1e-24      8.311      0.000    6.98e-24    1.13e-23
# x1          2.506e-17   3.02e-18      8.311      0.000    1.91e-17     3.1e-17
# x2          2.874e-20   3.46e-21      8.311      0.000    2.19e-20    3.56e-20
# x3          9.951e-20    1.2e-20      8.311      0.000    7.59e-20    1.23e-19
# x4          2.076e-18    2.5e-19      8.311      0.000    1.58e-18    2.57e-18
# x5          3.988e-17    4.8e-18      8.312      0.000    3.04e-17    4.93e-17
# x6          6.667e-16   8.02e-17      8.312      0.000    5.09e-16    8.25e-16
# x7           8.72e-15   1.05e-15      8.313      0.000    6.65e-15    1.08e-14
# x8          6.793e-14   8.17e-15      8.315      0.000    5.18e-14     8.4e-14
# x9         -6.315e-15   8.03e-16     -7.862      0.000    -7.9e-15   -4.73e-15
# x10         2.319e-16    3.1e-17      7.484      0.000    1.71e-16    2.93e-16
# x11        -4.216e-18   5.89e-19     -7.163      0.000   -5.38e-18   -3.06e-18
# x12         3.797e-20   5.51e-21      6.887      0.000    2.71e-20    4.88e-20
# x13        -1.356e-22   2.04e-23     -6.648      0.000   -1.76e-22   -9.54e-23
# ==============================================================================
# Omnibus:                       10.245   Durbin-Watson:                   0.756
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.730
# Skew:                          -0.510   Prob(JB):                      0.00468
# Kurtosis:                       2.696   Cond. No.                     4.99e+26
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.99e+26. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -4.924
# Model:                            OLS   Adj. R-squared:                 -5.058
# Method:                 Least Squares   F-statistic:                    -36.74
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:11   Log-Likelihood:                 1463.2
# No. Observations:                 227   AIC:                            -2914.
# Df Residuals:                     221   BIC:                            -2894.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.575e-27   7.76e-28      7.188      0.000    4.05e-27     7.1e-27
# x1         -4.431e-19   6.17e-20     -7.188      0.000   -5.65e-19   -3.22e-19
# x2          1.321e-22   1.84e-23      7.188      0.000    9.59e-23    1.68e-22
# x3          8.195e-23   1.14e-23      7.188      0.000    5.95e-23    1.04e-22
# x4          1.937e-21    2.7e-22      7.188      0.000    1.41e-21    2.47e-21
# x5          4.318e-20   6.01e-21      7.188      0.000    3.13e-20     5.5e-20
# x6          8.786e-19   1.22e-19      7.188      0.000    6.38e-19    1.12e-18
# x7          1.544e-17   2.15e-18      7.188      0.000    1.12e-17    1.97e-17
# x8          2.109e-16   2.93e-17      7.189      0.000    1.53e-16    2.69e-16
# x9          1.707e-15   2.37e-16      7.191      0.000    1.24e-15    2.18e-15
# x10        -1.558e-16   2.28e-17     -6.837      0.000   -2.01e-16   -1.11e-16
# x11         5.625e-18   8.61e-19      6.536      0.000    3.93e-18    7.32e-18
# x12        -1.007e-19    1.6e-20     -6.276      0.000   -1.32e-19   -6.91e-20
# x13         8.941e-22   1.48e-22      6.051      0.000    6.03e-22    1.19e-21
# x14        -3.152e-24   5.38e-25     -5.854      0.000   -4.21e-24   -2.09e-24
# ==============================================================================
# Omnibus:                       13.430   Durbin-Watson:                   0.660
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.729
# Skew:                          -0.623   Prob(JB):                     0.000633
# Kurtosis:                       2.929   Cond. No.                     2.64e+28
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.64e+28. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               ASD_rate   R-squared:                      -5.468
# Model:                            OLS   Adj. R-squared:                 -5.615
# Method:                 Least Squares   F-statistic:                    -37.37
# Date:                Thu, 27 Apr 2023   Prob (F-statistic):               1.00
# Time:                        13:53:12   Log-Likelihood:                 1453.2
# No. Observations:                 227   AIC:                            -2894.
# Df Residuals:                     221   BIC:                            -2874.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.183e-30   4.93e-31      6.460      0.000    2.21e-30    4.15e-30
# x1          3.466e-20   5.37e-21      6.460      0.000    2.41e-20    4.52e-20
# x2         -1.888e-23   2.92e-24     -6.460      0.000   -2.46e-23   -1.31e-23
# x3          8.409e-26    1.3e-26      6.460      0.000    5.84e-26     1.1e-25
# x4          1.573e-24   2.44e-25      6.460      0.000    1.09e-24    2.05e-24
# x5          3.919e-23   6.07e-24      6.460      0.000    2.72e-23    5.11e-23
# x6          9.157e-22   1.42e-22      6.461      0.000    6.36e-22     1.2e-21
# x7           1.94e-20      3e-21      6.461      0.000    1.35e-20    2.53e-20
# x8          3.532e-19   5.47e-20      6.461      0.000    2.45e-19    4.61e-19
# x9          4.974e-18    7.7e-19      6.461      0.000    3.46e-18    6.49e-18
# x10         4.136e-17    6.4e-18      6.463      0.000    2.87e-17     5.4e-17
# x11        -3.718e-18   6.02e-19     -6.176      0.000    -4.9e-18   -2.53e-18
# x12         1.323e-19   2.23e-20      5.929      0.000    8.83e-20    1.76e-19
# x13        -2.337e-21   4.09e-22     -5.713      0.000   -3.14e-21   -1.53e-21
# x14          2.05e-23   3.71e-24      5.524      0.000    1.32e-23    2.78e-23
# x15        -7.147e-26   1.33e-26     -5.356      0.000   -9.78e-26   -4.52e-26
# ==============================================================================
# Omnibus:                       17.618   Durbin-Watson:                   0.588
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.659
# Skew:                          -0.714   Prob(JB):                     5.38e-05
# Kurtosis:                       3.191   Cond. No.                     5.81e+30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.81e+30. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# More flexibility get Low MSE but meaningless and difficult to interpret
# And correlation is maintained despite the high flexibility.

# %% [markdown]
# ## 4. BoostStrap

# %%
def boot_fn(data, start_index, end_index, X_val, y_val):
    m = LinearRegression(fit_intercept=True).fit(
        data[X_val].iloc[start_index:end_index].values.reshape(-1, 1),
        data[y_val].iloc[start_index:end_index]
    )
    
    return m.intercept_, m.coef_

boot_fn(data, 0, len(data), 'Financial_Independence', 'ASD_rate')
# Out:
# (0.0003783280285715549, array([4.87333138e-06]))

# %%
boot_fn(resample(data, replace=True, n_samples=len(data)), 0, len(data), 'Financial_Independence', 'ASD_rate')
# Out:
# (0.0003717315447724586, array([5.43820456e-06]))

# %%
bs_boot = {'t1' : [], 't2':[]}

for i in range(0, 1000):
    bs_boot['t1'].append(
        boot_fn(resample(data, replace=True, n_samples=len(data)), 0, len(data), 'Financial_Independence', 'ASD_rate')[0]
    )
    bs_boot['t2'].append(
        boot_fn(resample(data, replace=True, n_samples=len(data)), 0, len(data), 'Financial_Independence', 'ASD_rate')[1][0]
    )
    
t1_es = np.array(bs_boot['t1']).mean()
t1_se = np.array(bs_boot['t1']).std()
t2_es = np.array(bs_boot['t2']).mean()
t2_se = np.array(bs_boot['t2']).std()

print('t1 bs estimate & se', t1_es, t1_se)
print('t2 bs estimate & se', t2_es, t2_se)

#Draw a graph (X=Financial_Independence(boot) Y=ASD_rate) with matplotlib
def predicBoot_function(x):
    return (t2_es*x + t1_es)
FI_Boot_x = np.arange(0, 70, 0.1)
FI_Boot_y = [predicBoot_function(x) for x in FI_Boot_x]
plt.scatter(data['Financial_Independence'], data['ASD_rate'])
plt.xlabel('Financial_Independence')
plt.ylabel('ASD_rate')
plt.plot(FI_Boot_x, FI_Boot_y)
plt.show()
# Out:
# t1 bs estimate & se 0.00037787941848975296 2.003831675280376e-05
# t2 bs estimate & se 4.869778929558552e-06 8.86770333043575e-07
