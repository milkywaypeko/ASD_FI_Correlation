# %%
#Import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
#Import Disabled Population Statistics
seoulD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Seoul.csv')
busanD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Busan.csv')
daeguD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Daegu.csv')
incheonD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Incheon.csv')
gwangjuD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Gwangju.csv')
daejeonD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Daejeon.csv')
ulsanD  = pd.read_csv('./Statistics/Disabled/Population of the disabled in Ulsan.csv')
sejongD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Sejong.csv')
gyeonggiD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Gyeonggi-do.csv')
gangwonD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Gangwon-do.csv')
nChungcheongD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Chungcheongbuk-do.csv')
sChungcheongD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Chungcheongnam-do.csv')
nJeollaD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Jeollabuk-do.csv')
sJeollaD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Jeollanam-do.csv')
nGyeongsangD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Gyeongsangbuk-do.csv')
sGyeongsangD = pd.read_csv('./Statistics/Disabled/Population of the disabled in Gyeongsangnam-do.csv')
jejuD =  pd.read_csv('./Statistics/Disabled/Population of the disabled in Jeju.csv')

#Label Disabled Population Statistics
seoulD.insert(0, '광역자치단체', '서울특별시')
busanD.insert(0, '광역자치단체', '부산광역시')
daeguD.insert(0, '광역자치단체', '대구광역시')
incheonD.insert(0, '광역자치단체', '인천광역시')
gwangjuD.insert(0, '광역자치단체', '광주광역시')
daejeonD.insert(0, '광역자치단체', '대전광역시')
ulsanD.insert(0, '광역자치단체', '울산광역시')
sejongD.insert(0, '광역자치단체', '세종특별자치시')
gyeonggiD.insert(0, '광역자치단체', '경기도')
gyeonggiD.drop('남/북',axis=1, inplace=True)
gangwonD.insert(0, '광역자치단체', '강원도')
nChungcheongD.insert(0, '광역자치단체', '충청북도')
sChungcheongD.insert(0, '광역자치단체', '충청남도')
nJeollaD.insert(0, '광역자치단체', '전라북도')
sJeollaD.insert(0, '광역자치단체', '전라남도')
nGyeongsangD.insert(0, '광역자치단체', '경상북도')
sGyeongsangD.insert(0, '광역자치단체', '경상남도')
jejuD.insert(0, '광역자치단체', '제주특별자치도')

# %%
#Import Population Statistics
seoulP = pd.read_csv('./Statistics/Population/Resident population of Seoul.csv')
busanP = pd.read_csv('./Statistics/Population/Resident population of Busan.csv')
daeguP = pd.read_csv('./Statistics/Population/Resident population of Daegu.csv')
incheonP = pd.read_csv('./Statistics/Population/Resident population of Incheon.csv')
gwangjuP = pd.read_csv('./Statistics/Population/Resident population of Gwangju.csv')
daejeonP = pd.read_csv('./Statistics/Population/Resident population of Daejeon.csv')
ulsanP  = pd.read_csv('./Statistics/Population/Resident population of Ulsan.csv')
sejongP = pd.read_csv('./Statistics/Population/Resident population of Sejong.csv')
gyeonggiP = pd.read_csv('./Statistics/Population/Resident population of Gyeonggi-do.csv')
gangwonP = pd.read_csv('./Statistics/Population/Resident population of Gangwon-do.csv')
nChungcheongP = pd.read_csv('./Statistics/Population/Resident population of Chungcheongbuk-do.csv')
sChungcheongP = pd.read_csv('./Statistics/Population/Resident population of Chungcheongnam-do.csv')
nJeollaP = pd.read_csv('./Statistics/Population/Resident population of Jeollabuk-do.csv')
sJeollaP = pd.read_csv('./Statistics/Population/Resident population of Jeollanam-do.csv')
nGyeongsangP = pd.read_csv('./Statistics/Population/Resident population of Gyeongsangbuk-do.csv')
sGyeongsangP = pd.read_csv('./Statistics/Population/Resident population of Gyeongsangnam-do.csv')
jejuP =  pd.read_csv('./Statistics/Population/Resident population of Jeju.csv')

#Label Population Statistics
seoulP.insert(0, '광역자치단체', '서울특별시')
busanP.insert(0, '광역자치단체', '부산광역시')
daeguP.insert(0, '광역자치단체', '대구광역시')
incheonP.insert(0, '광역자치단체', '인천광역시')
gwangjuP.insert(0, '광역자치단체', '광주광역시')
daejeonP.insert(0, '광역자치단체', '대전광역시')
ulsanP.insert(0, '광역자치단체', '울산광역시')
sejongP.insert(0, '광역자치단체', '세종특별자치시')
gyeonggiP.insert(0, '광역자치단체', '경기도')
gyeonggiP.drop('남/북',axis=1, inplace=True)
gangwonP.insert(0, '광역자치단체', '강원도')
nChungcheongP.insert(0, '광역자치단체', '충청북도')
sChungcheongP.insert(0, '광역자치단체', '충청남도')
nJeollaP.insert(0, '광역자치단체', '전라북도')
sJeollaP.insert(0, '광역자치단체', '전라남도')
nGyeongsangP.insert(0, '광역자치단체', '경상북도')
sGyeongsangP.insert(0, '광역자치단체', '경상남도')
jejuP.insert(0, '광역자치단체', '제주특별자치도')

# %%
#Import Financial independence  Statistics
seoulF = pd.read_csv('./Statistics/Finance/Financial independence of Seoul.csv')
busanF = pd.read_csv('./Statistics/Finance/Financial Independence of Busan.csv')
daeguF = pd.read_csv('./Statistics/Finance/Financial Independence of Daegu.csv')
incheonF = pd.read_csv('./Statistics/Finance/Financial Independence of Incheon.csv')
gwangjuF = pd.read_csv('./Statistics/Finance/Financial Independence of Gwangju.csv')
daejeonF = pd.read_csv('./Statistics/Finance/Financial Independence of Daejeon.csv')
ulsanF  = pd.read_csv('./Statistics/Finance/Financial Independence of Ulsan.csv')
sejongF = pd.read_csv('./Statistics/Finance/Financial Independence of Sejong.csv')
gyeonggiF = pd.read_csv('./Statistics/Finance/Financial independence of Gyeonggi-do.csv')
gangwonF = pd.read_csv('./Statistics/Finance/Financial Independence in Gangwon-do.csv')
nChungcheongF = pd.read_csv('./Statistics/Finance/Financial Independence in Chungcheongbuk-do.csv')
sChungcheongF = pd.read_csv('./Statistics/Finance/Financial Independence in Chungcheongnam-do.csv')
nJeollaF = pd.read_csv('./Statistics/Finance/Financial Independence in Jeollabuk-do.csv')
sJeollaF = pd.read_csv('./Statistics/Finance/Financial independence of Jeollanam-do.csv')
nGyeongsangF = pd.read_csv('./Statistics/Finance/Financial independence of Gyeongsangbuk-do.csv')
sGyeongsangF = pd.read_csv('./Statistics/Finance/Financial independence of Gyeongsangnam-do.csv')
jejuF = pd.read_csv('./Statistics/Finance/Financial independence of Jeju.csv')

#Label Financial independence Statistics
seoulF.insert(0, '광역자치단체', '서울특별시')
busanF.insert(0, '광역자치단체', '부산광역시')
daeguF.insert(0, '광역자치단체', '대구광역시')
incheonF.insert(0, '광역자치단체', '인천광역시')
gwangjuF.insert(0, '광역자치단체', '광주광역시')
daejeonF.insert(0, '광역자치단체', '대전광역시')
ulsanF.insert(0, '광역자치단체', '울산광역시')
sejongF.insert(0, '광역자치단체', '세종특별자치시')
gyeonggiF.insert(0, '광역자치단체', '경기도')
gyeonggiF.drop('시/군',axis=1, inplace=True)
gangwonF.insert(0, '광역자치단체', '강원도')
nChungcheongF.insert(0, '광역자치단체', '충청북도')
sChungcheongF.insert(0, '광역자치단체', '충청남도')
nJeollaF.insert(0, '광역자치단체', '전라북도')
sJeollaF.insert(0, '광역자치단체', '전라남도')
nGyeongsangF.insert(0, '광역자치단체', '경상북도')
sGyeongsangF.insert(0, '광역자치단체', '경상남도')
jejuF.insert(0, '광역자치단체', '제주특별자치도')

# %%
#Connect Disabled Population Statistics
neurodivergent = pd.concat([seoulD, busanD, daeguD, incheonD, gwangjuD, daejeonD, ulsanD, sejongD, gyeonggiD, gangwonD, nChungcheongD, sChungcheongD, nJeollaD,sJeollaD, nGyeongsangD, sGyeongsangD, jejuD], ignore_index=True)

# %%
#Connect Population Statistics
population = pd.concat([seoulP, busanP, daeguP, incheonP, gwangjuP, daejeonP, ulsanP, sejongP, gyeonggiP, gangwonP, nChungcheongP, sChungcheongP, nJeollaP, sJeollaP, nGyeongsangP, sGyeongsangP, jejuP], ignore_index=True)

# %%
#Connect Finance Statistics
finance = pd.concat([seoulF, busanF, daeguF, incheonF, gwangjuF, daejeonF, ulsanF, sejongF, gyeonggiF, gangwonF, nChungcheongF, sChungcheongF, nJeollaF,sJeollaF, nGyeongsangF, sGyeongsangF, jejuF], ignore_index=True)

# %%
#Merge All Statistics
temp = pd.merge(neurodivergent,population)
data = pd.merge(temp, finance)

# %%
#Make Statistics For Developmental Disability
data['발달장애'] = data['지적장애'] + data['자폐성']

#Make Rate of Intellectual disability
data['지적장애_비율'] = data['지적장애'] / data['인구']

#Make Rate of Autistic Spectrum Disorder
data['자폐성_비율'] = data['자폐성'] / data['인구']

#Make Rate of Developmental Disability
data['발달장애_비율'] = data['발달장애'] / data['인구']

#Make Rate of Developmental Disability of Autistic Spectrum Disorder
data['발달_자폐성_비율'] = data['자폐성'] / data['발달장애']

#For label in english
data.rename(columns = {'광역자치단체' : 'RLG', '기초자치단체' : 'BLG', '지적장애' : 'ID', '자폐성' : 'ASD', '인구' : 'Population',  '재정자립도 (%)' : 'Financial_Independence', '재정자주도 (%)' : 'Financial_often', '발달장애' : 'DD', '지적장애_비율' : 'ID_rate', '자폐성_비율':'ASD_rate', '발달장애_비율' : 'DD_rate', '발달_자폐성_비율':'DD_ASD_rate'}, inplace = True)

#Column arrange
data = data[['RLG', 'BLG', 'ID', 'ASD', 'DD', 'Population', 'ID_rate', 'ASD_rate', 'DD_rate', 'DD_ASD_rate', 'Financial_Independence', 'Financial_often']]

data
# Out:
#          RLG      BLG    ID  ASD    DD  Population   ID_rate  ASD_rate  \
# 0      서울특별시      종로구   396  111   507      161869  0.002446  0.000686
# 1      서울특별시       중구   304   67   371      136488  0.002227  0.000491
# 2      서울특별시      용산구   530  106   636      245185  0.002162  0.000432
# 3      서울특별시      성동구   710  174   884      308979  0.002298  0.000563
# 4      서울특별시      광진구   818  167   985      366972  0.002229  0.000455
# ..       ...      ...   ...  ...   ...         ...       ...       ...
# 222     경상남도      산청군   322   19   341       35430  0.009088  0.000536
# 223     경상남도      함양군   250   16   266       39506  0.006328  0.000405
# 224     경상남도      거창군   382   26   408       62005  0.006161  0.000419
# 225     경상남도      합천군   382   14   396       44582  0.008568  0.000314
# 226  제주특별자치도  제주특별자치도  3393  617  4010      697578  0.004864  0.000884
#
#       DD_rate  DD_ASD_rate  Financial_Independence  Financial_often
# ...

# %%
#Drow for find Correlation
sns.pairplot(data)

# %%
#Linear regression (X=Financial_Independence Y=ASD_rate) with statsmodels.formula.api  of scikit-learn 
ASD_rate_ols_smf = smf.ols(formula='ASD_rate ~ Financial_Independence', data=data)

ASD_rate_ols_smf_results = ASD_rate_ols_smf.fit()
ASD_rate_ols_smf_results.summary()

# %%
#Draw a graph (X=Financial_Independence Y=ASD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='ASD_rate', data=data)

# %%
#Linear regression (X=Financial_Independence Y=ID_rate) with statsmodels.formula.api  of scikit-learn 
ols_smf = smf.ols(formula='ID_rate ~ Financial_Independence', data=data)

ols_smf_results = ols_smf.fit()
ols_smf_results.summary()

# %%
#Draw a graph (X=Financial_Independence Y=ID_rate) with seaborn
sns.regplot(x='Financial_Independence', y='ID_rate', data=data)

# %%
#Linear regression (X=Financial_Independence Y=DD_rate) with statsmodels.formula.api  of scikit-learn 
ols_smf = smf.ols(formula='DD_rate ~ Financial_Independence', data=data)

ols_smf_results = ols_smf.fit()
ols_smf_results.summary()

# %%
#Draw a graph (X=Financial_Independence Y=DD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='DD_rate', data=data)

# %%
#Linear regression (X=Financial_Independence Y=DD_ASD_rate) with statsmodels.formula.api  of scikit-learn 
ols_smf = smf.ols(formula='DD_ASD_rate ~ Financial_Independence', data=data)

ols_smf_results = ols_smf.fit()
ols_smf_results.summary()

# %%
#Draw a graph (X=Financial_Independence Y=DD_ASD_rate) with seaborn
sns.regplot(x='Financial_Independence', y='DD_ASD_rate', data=data)
